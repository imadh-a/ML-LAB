# %%
import math
import csv
from sklearn.metrics import accuracy_score

from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
def load_csv(filename):
    lines = csv.reader(open(filename, "r"))
    dataset = list(lines)
    headers = dataset.pop(0)
    return dataset, headers

class Node:
    def __init__(self, attribute):
        self.attribute = attribute
        self.children = []
        self.answer = ""

def subtables(data, col, delete):
    dic = {}
    coldata = [row[col] for row in data]
    attr = list(set(coldata))

    counts = [0] * len(attr)
    r = len(data)
    c = len(data[0])
    for x in range(len(attr)):
        for y in range(r):
            if data[y][col] == attr[x]:
                counts[x] += 1

    for x in range(len(attr)):
        dic[attr[x]] = [[0 for i in range(c)] for j in range(counts[x])]
        pos = 0
        for y in range(r):
            if data[y][col] == attr[x]:
                if delete:
                    del data[y][col]
                dic[attr[x]][pos] = data[y]
                pos += 1
    return attr, dic

def entropy(S):
    attr = list(set(S))
    if len(attr) == 1:
        return 0

    counts = [0, 0]
    for i in range(2):
        counts[i] = sum([1 for x in S if attr[i] == x]) / (len(S) * 1.0)

    sums = 0
    for cnt in counts:
        sums += -1 * cnt * math.log(cnt, 2)
    return sums

def compute_gain(data, col):
    attr, dic = subtables(data, col, delete=False)

    total_size = len(data)
    entropies = [0] * len(attr)
    ratio = [0] * len(attr)

    total_entropy = entropy([row[-1] for row in data])
    for x in range(len(attr)):
        ratio[x] = len(dic[attr[x]]) / (total_size * 1.0)
        entropies[x] = entropy([row[-1] for row in dic[attr[x]]])
        total_entropy -= ratio[x] * entropies[x]
    return total_entropy

def build_tree(data, features):
    lastcol = [row[-1] for row in data]
    if len(set(lastcol)) == 1:
        node = Node("")
        node.answer = lastcol[0]
        return node

    n = len(data[0]) - 1
    gains = [0] * n
    for col in range(n):
        gains[col] = compute_gain(data, col)
    split = gains.index(max(gains))
    node = Node(features[split])
    fea = features[:split] + features[split + 1:]

    attr, dic = subtables(data, split, delete=True)

    for x in range(len(attr)):
        child = build_tree(dic[attr[x]], fea)
        node.children.append((attr[x], child))
    return node

def print_tree(node, level):
    if node.answer != "":
        print("  " * level, node.answer)
        return

    print("  " * level, node.attribute)
    for value, n in node.children:
        print("  " * (level + 1), value)
        print_tree(n, level + 2)

def classify(node, x_test, features):
    if node.answer != "":
        return node.answer
    pos = features.index(node.attribute)
    for value, n in node.children:
        if x_test[pos] == value:
            return classify(n, x_test, features)

'''Main program'''
dataset, features = load_csv("/content/drive/MyDrive/ML LAB FINAL/Decision Tree/PlayTennis_1BM20CS059.csv")
node1 = build_tree(dataset, features)

print("The decision tree for the dataset using ID3 algorithm is")
print_tree(node1, 0)

testdata, features = load_csv("/content/drive/MyDrive/ML LAB FINAL/Decision Tree/PlayTennis_1BM20CS059.csv")

test_instances = [instance[:-1] for instance in testdata]
true_labels = [instance[-1] for instance in testdata]

predicted_labels = []
for xtest in test_instances:
    predicted_label = classify(node1, xtest, features)
    predicted_labels.append(predicted_label)

accuracy = accuracy_score(true_labels, predicted_labels)
print("Accuracy:", accuracy)
# Out:
# The decision tree for the dataset using ID3 algorithm is
#  Outlook
#    Rain
#      Wind
#        Weak
#          Yes
#        Strong
#          No
#    Sunny
#      Humidity
#        High
#          No
#        Normal
#          Yes
#    Overcast
#      Yes
# Accuracy: 1.0

# %%
def load_csv(filename):
    lines = csv.reader(open(filename, "r"))
    dataset = list(lines)
    headers = dataset.pop(0)
    return dataset, headers

class Node:
    def __init__(self, attribute):
        self.attribute = attribute
        self.children = []
        self.answer = ""

def subtables(data, col, delete):
    dic = {}
    coldata = [row[col] for row in data]
    attr = list(set(coldata))

    counts = [0] * len(attr)
    r = len(data)
    c = len(data[0])
    for x in range(len(attr)):
        for y in range(r):
            if data[y][col] == attr[x]:
                counts[x] += 1

    for x in range(len(attr)):
        dic[attr[x]] = [[0 for i in range(c)] for j in range(counts[x])]
        pos = 0
        for y in range(r):
            if data[y][col] == attr[x]:
                if delete:
                    del data[y][col]
                dic[attr[x]][pos] = data[y]
                pos += 1
    return attr, dic

def entropy(S):
    attr = list(set(S))
    if len(attr) == 1:
        return 0

    counts = [0, 0]
    for i in range(2):
        counts[i] = sum([1 for x in S if attr[i] == x]) / (len(S) * 1.0)

    sums = 0
    for cnt in counts:
        sums += -1 * cnt * math.log(cnt, 2)
    return sums

def compute_gain(data, col):
    attr, dic = subtables(data, col, delete=False)

    total_size = len(data)
    entropies = [0] * len(attr)
    ratio = [0] * len(attr)

    total_entropy = entropy([row[-1] for row in data])
    for x in range(len(attr)):
        ratio[x] = len(dic[attr[x]]) / (total_size * 1.0)
        entropies[x] = entropy([row[-1] for row in dic[attr[x]]])
        total_entropy -= ratio[x] * entropies[x]
    return total_entropy

def build_tree(data, features):
    lastcol = [row[-1] for row in data]
    if len(set(lastcol)) == 1:
        node = Node("")
        node.answer = lastcol[0]
        return node

    n = len(data[0]) - 1
    gains = [0] * n
    for col in range(n):
        gains[col] = compute_gain(data, col)
    split = gains.index(max(gains))
    node = Node(features[split])
    fea = features[:split] + features[split + 1:]

    attr, dic = subtables(data, split, delete=True)

    for x in range(len(attr)):
        child = build_tree(dic[attr[x]], fea)
        node.children.append((attr[x], child))
    return node

def print_tree(node, level):
    if node.answer != "":
        print("  " * level, node.answer)
        return

    print("  " * level, node.attribute)
    for value, n in node.children:
        print("  " * (level + 1), value)
        print_tree(n, level + 2)

def classify(node, x_test, features):
    if node.answer != "":
        return node.answer
    pos = features.index(node.attribute)
    for value, n in node.children:
        if x_test[pos] == value:
            return classify(n, x_test, features)

'''Main program'''
dataset, features = load_csv("/content/drive/MyDrive/ML LAB FINAL/Decision Tree/new.csv")
node1 = build_tree(dataset, features)

print("The decision tree for the dataset using ID3 algorithm is")
print_tree(node1, 0)

testdata, features = load_csv("/content/drive/MyDrive/ML LAB FINAL/Decision Tree/new.csv")

test_instances = [instance[:-1] for instance in testdata]
true_labels = [instance[-1] for instance in testdata]

predicted_labels = []
for xtest in test_instances:
    predicted_label = classify(node1, xtest, features)
    predicted_labels.append(predicted_label)

accuracy = accuracy_score(true_labels, predicted_labels)
print("Accuracy:", accuracy)
# Out:
# The decision tree for the dataset using ID3 algorithm is
#  Age_Group
#    Below_35
#      Car_Bought
#        No
#          Gender
#            Female
#              Marital_Status
#                Married
#                  Graduate
#                Single
#                  Undergraduate
#            Male
#              Marital_Status
#                Married
#                  Undergraduate
#                Single
#                  Graduate
#        Yes
#          Undergraduate
#    35_50
#      Postgraduate
#    Above_50
#      Gender
#        Female
#          Marital_Status
#            Married
#              Undergraduate
#            Single
#              Graduate
#        Male
#          Graduate
# Accuracy: 1.0

# %%
def load_csv(filename):
    lines = csv.reader(open(filename, "r"))
    dataset = list(lines)
    headers = dataset.pop(0)
    return dataset, headers

class Node:
    def __init__(self, attribute):
        self.attribute = attribute
        self.children = []
        self.answer = ""

def subtables(data, col, delete):
    dic = {}
    coldata = [row[col] for row in data]
    attr = list(set(coldata))

    counts = [0] * len(attr)
    r = len(data)
    c = len(data[0])
    for x in range(len(attr)):
        for y in range(r):
            if data[y][col] == attr[x]:
                counts[x] += 1

    for x in range(len(attr)):
        dic[attr[x]] = [[0 for i in range(c)] for j in range(counts[x])]
        pos = 0
        for y in range(r):
            if data[y][col] == attr[x]:
                if delete:
                    del data[y][col]
                dic[attr[x]][pos] = data[y]
                pos += 1
    return attr, dic

def entropy(S):
    attr = list(set(S))
    if len(attr) == 1:
        return 0

    counts = [0, 0]
    for i in range(2):
        counts[i] = sum([1 for x in S if attr[i] == x]) / (len(S) * 1.0)

    sums = 0
    for cnt in counts:
        sums += -1 * cnt * math.log(cnt, 2)
    return sums

def compute_gain(data, col):
    attr, dic = subtables(data, col, delete=False)

    total_size = len(data)
    entropies = [0] * len(attr)
    ratio = [0] * len(attr)

    total_entropy = entropy([row[-1] for row in data])
    for x in range(len(attr)):
        ratio[x] = len(dic[attr[x]]) / (total_size * 1.0)
        entropies[x] = entropy([row[-1] for row in dic[attr[x]]])
        total_entropy -= ratio[x] * entropies[x]
    return total_entropy

def build_tree(data, features):
    lastcol = [row[-1] for row in data]
    if len(set(lastcol)) == 1:
        node = Node("")
        node.answer = lastcol[0]
        return node

    n = len(data[0]) - 1
    gains = [0] * n
    for col in range(n):
        gains[col] = compute_gain(data, col)
    split = gains.index(max(gains))
    node = Node(features[split])
    fea = features[:split] + features[split + 1:]

    attr, dic = subtables(data, split, delete=True)

    for x in range(len(attr)):
        child = build_tree(dic[attr[x]], fea)
        node.children.append((attr[x], child))
    return node

def print_tree(node, level):
    if node.answer != "":
        print("  " * level, node.answer)
        return

    print("  " * level, node.attribute)
    for value, n in node.children:
        print("  " * (level + 1), value)
        print_tree(n, level + 2)

def classify(node, x_test, features):
    if node.answer != "":
        return node.answer
    pos = features.index(node.attribute)
    for value, n in node.children:
        if x_test[pos] == value:
            return classify(n, x_test, features)

'''Main program'''
dataset, features = load_csv("/content/drive/MyDrive/ML LAB FINAL/Decision Tree/drug200.csv")
node1 = build_tree(dataset, features)

print("The decision tree for the dataset using ID3 algorithm is")
print_tree(node1, 0)

testdata, features = load_csv("/content/drive/MyDrive/ML LAB FINAL/Decision Tree/drug200.csv")

test_instances = [instance[:-1] for instance in testdata]
true_labels = [instance[-1] for instance in testdata]

predicted_labels = []
for xtest in test_instances:
    predicted_label = classify(node1, xtest, features)
    predicted_labels.append(predicted_label)

accuracy = accuracy_score(true_labels, predicted_labels)
print("Accuracy:", accuracy)
# Out:
# The decision tree for the dataset using ID3 algorithm is
#  Na_to_K
#    19.675
#      drugY
#    13.769
#      drugX
#    11.455
#      drugX
#    19.368
#      drugY
#    16.85
#      drugY
#    6.683
#      drugX
#    9.443
#      drugX
#    6.769
#      drugC
#    11.567
#      drugC
#    9.945
#      drugB
#    12.495
#      drugB
#    18.809
#      drugY
#    8.621
#      drugB
#    38.247
#      drugY
#    33.542
#      drugY
#    11.34
#      drugB
#    23.091
#      drugY
#    18.703
#      drugY
#    15.156
#      drugY
#    25.741
#      drugY
#    12.854
#      drugA
#    15.436
#      drugY
#    11.871
#      drugA
#    34.997
#      drugY
#    27.183
#      drugY
#    13.972
#      drugA
#    8.968
#      drugX
#    15.49
#      drugY
#    9.849
#      drugB
#    18.991
#      drugY
#    12.879
#      drugX
#    19.011
#      drugY
#    19.128
#      drugY
#    11.424
#      drugX
#    15.036
#      drugY
#    12.859
#      drugX
#    10.091
#      drugX
#    15.015
#      drugY
#    20.693
#      drugY
#    29.45
#      drugY
#    12.894
#      drugA
#    10.84
#      drugX
#    34.686
#      drugY
#    12.307
#      drugA
#    17.206
#      drugY
#    9.712
#      drugC
#    11.939
#      drugX
#    10.189
#      drugB
#    25.786
#      drugY
#    15.79
#      drugY
#    9.677
#      drugB
#    13.935
#      drugB
#    13.598
#      drugX
#    16.753
#      drugY
#    9.445
#      drugA
#    9.084
#      drugX
#    15.969
#      drugY
#    10.443
#      drugX
#    20.489
#      drugY
#    28.632
#      drugY
#    11.262
#      drugA
#    16.347
#      drugY
#    16.31
#      drugY
#    13.597
#      drugX
#    11.326
#      drugA
#    25.395
#      drugY
#    11.227
#      drugA
#    7.798
#      drugX
#    22.818
#      drugY
#    20.013
#      drugY
#    9.514
#      drugX
#    20.932
#      drugY
#    19.199
#      drugY
#    18.457
#      drugY
#    27.064
#      drugY
#    24.276
#      drugY
#    10.977
#      drugB
#    16.724
#      drugY
#    32.922
#      drugY
#    9.381
#      drugX
#    18.295
#      drugY
#    13.313
#      drugA
#    17.069
#      drugY
#    7.49
#      drugA
#    10.292
#      drugA
#    9.709
#      drugX
#    20.909
#      drugY
#    17.211
#      drugY
#    8.151
#      drugC
#    10.898
#      drugX
#    9.567
#      drugB
#    14.133
#      drugX
#    8.107
#      drugX
#    19.796
#      drugY
#    19.161
#      drugY
#    16.275
#      drugY
#    8.7
#      drugA
#    24.658
#      drugY
#    12.295
#      drugX
#    18.739
#      drugY
#    10.065
#      drugX
#    16.594
#      drugY
#    10.537
#      drugC
#    25.917
#      drugY
#    10.832
#      drugX
#    15.891
#      drugY
#    17.225
#      drugY
#    16.725
#      drugY
#    6.269
#      drugA
#    13.091
#      drugA
#    7.845
#      drugX
#    11.953
#      drugX
#    10.444
#      drugC
#    35.639
#      drugY
#    31.876
#      drugY
#    15.478
#      drugY
#    8.011
#      drugA
#    8.607
#      drugX
#    25.475
#      drugY
#    11.009
#      drugB
#    8.966
#      drugX
#    12.006
#      Age
#        37
#          drugX
#        16
#          drugC
#    13.938
#      drugX
#    19.007
#      drugY
#    9.475
#      drugA
#    10.067
#      drugC
#    19.221
#      drugY
#    10.291
#      drugC
#    27.05
#      drugY
#    30.568
#      drugY
#    12.703
#      drugX
#    11.349
#      drugX
#    7.298
#      drugC
#    12.26
#      drugX
#    17.951
#      drugY
#    19.416
#      drugY
#    12.766
#      drugA
#    10.017
#      drugX
#    13.967
#      drugB
#    9.281
#      drugX
#    9.894
#      drugX
#    13.934
#      drugB
#    23.003
#      drugY
#    11.014
#      drugX
#    10.103
#      drugX
#    33.486
#      drugY
#    25.355
#      drugY
#    29.271
#      drugY
#    9.17
#      drugX
#    7.261
#      drugX
#    11.686
#      drugX
#    10.403
#      drugA
#    21.036
#      drugY
#    11.037
#      drugC
#    18.348
#      drugY
#    22.456
#      drugY
#    7.34
#      drugX
#    25.969
#      drugY
#    22.963
#      drugY
#    31.686
#      drugY
#    25.974
#      drugY
#    15.516
#      drugY
#    10.605
#      drugX
#    29.875
#      drugY
#    9.664
#      drugA
#    14.642
#      drugX
#    14.16
#      drugC
#    14.02
#      drugX
#    14.239
#      drugB
#    7.477
#      drugX
#    7.761
#      drugX
#    28.294
#      drugY
#    14.216
#      drugX
#    13.127
#      drugC
#    15.376
#      drugY
#    12.923
#      drugX
#    26.645
#      drugY
#    15.171
#      drugY
#    13.093
#      drugC
#    7.285
#      drugX
#    25.893
#      drugY
#    13.884
#      drugX
#    37.188
#      drugY
#    8.37
#      drugX
#    11.767
#      drugC
#    10.114
#      drugC
#    20.942
#      drugY
#    12.856
#      drugA
#    13.303
#      drugB
#    11.343
#      drugB
#    22.697
#      drugY
#    8.75
#      drugX
#    10.446
#      drugA
#    30.366
#      drugY
#    11.198
#      drugA
#    22.905
#      drugY
#    27.826
#      drugY
#    18.043
#      drugY
# Accuracy: 1.0
